# %% [markdown]
# Importing Packages

# %%
import pandas as pd
from scipy import sparse

ratings = pd.read_csv('datasets/ratings.csv')
movies = pd.read_csv('datasets/movies.csv')

# %% [markdown]
# Merging movies.csv and ratings.csv

# %%
ratings = pd.merge(movies,ratings).drop(['genres','timestamp'],axis=1)
print(ratings.shape)
ratings.head()
# Out:
# (100836, 4)
#    movieId             title  userId  rating
# 0        1  Toy Story (1995)       1     4.0
# 1        1  Toy Story (1995)       5     4.0
# 2        1  Toy Story (1995)       7     4.5
# 3        1  Toy Story (1995)      15     2.5
# 4        1  Toy Story (1995)      17     4.5

# %% [markdown]
# Indexing the table according to the userId

# %%
userRatings = ratings.pivot_table(index=['userId'],columns=['title'],values='rating')
userRatings.head()
# Out:
# title   '71 (2014)  'Hellboy': The Seeds of Creation (2004)  \
# userId
# 1              NaN                                      NaN
# 2              NaN                                      NaN
# 3              NaN                                      NaN
# 4              NaN                                      NaN
# 5              NaN                                      NaN
#
# title   'Round Midnight (1986)  'Salem's Lot (2004)  \
# userId
# 1                          NaN                  NaN
# 2                          NaN                  NaN
# 3                          NaN                  NaN
# 4                          NaN                  NaN
# 5                          NaN                  NaN
#
# title   'Til There Was You (1997)  'Tis the Season for Love (2015)  \
# userId
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# ...

# %% [markdown]
# Removing non significant movies to reduce the noise in the dataset
# i.e. All the movies with less than 10 reviews

# %%
print("Before: ",userRatings.shape)
userRatings = userRatings.dropna(thresh=10, axis=1).fillna(0,axis=1)
print("After: ",userRatings.shape)
# Out:
# Before:  (610, 9719)
# After:  (610, 2269)

# %% [markdown]
# Creating the similarity matrix

# %%
corrMatrix = userRatings.corr(method='pearson')
corrMatrix.head()
# Out:
# title                              'burbs, The (1989)  \
# title
# 'burbs, The (1989)                           1.000000
# (500) Days of Summer (2009)                  0.063117
# 10 Cloverfield Lane (2016)                  -0.023768
# 10 Things I Hate About You (1999)            0.143482
# 10,000 BC (2008)                             0.011998
#
# title                              (500) Days of Summer (2009)  \
# title
# 'burbs, The (1989)                                    0.063117
# (500) Days of Summer (2009)                           1.000000
# 10 Cloverfield Lane (2016)                            0.142471
# 10 Things I Hate About You (1999)                     0.273989
# 10,000 BC (2008)                                      0.193960
#
# title                              10 Cloverfield Lane (2016)  \
# title
# 'burbs, The (1989)                                  -0.023768
# (500) Days of Summer (2009)                          0.142471
# ...

# %% [markdown]
# Storing the DataFrame for further uses

# %%
df_new = pd.DataFrame(data = corrMatrix, 
                      columns = userRatings.columns)


df_new.to_csv('datasets/item_similarity_df.csv')

# %% [markdown]
# Verifying the data stored in the csv file

# %%
df = pd.read_csv('datasets/item_similarity_df.csv')
df.head()
# Out:
#                                title  'burbs, The (1989)  \
# 0                 'burbs, The (1989)            1.000000
# 1        (500) Days of Summer (2009)            0.063117
# 2         10 Cloverfield Lane (2016)           -0.023768
# 3  10 Things I Hate About You (1999)            0.143482
# 4                   10,000 BC (2008)            0.011998
#
#    (500) Days of Summer (2009)  10 Cloverfield Lane (2016)  \
# 0                     0.063117                   -0.023768
# 1                     1.000000                    0.142471
# 2                     0.142471                    1.000000
# 3                     0.273989                   -0.005799
# 4                     0.193960                    0.112396
#
#    10 Things I Hate About You (1999)  10,000 BC (2008)  101 Dalmatians (1996)  \
# 0                           0.143482          0.011998               0.087931
# 1                           0.273989          0.193960               0.148903
# ...
